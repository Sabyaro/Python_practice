# %%
import matplotlib.pyplot as plt
import numpy as np

#For the graph I 

y1 = 4
x1 = np.linspace(2,4,2)
y_value_1 = np.full_like(x1, y1)
plt.plot(x1,y_value_1)
#plt.show()

x2 = 3
y2 = np.linspace(1,4,4)
x_value_1 = np.full_like(y2,x2)
plt.plot(x_value_1,y2)
#plt.show()

y3 = 1
x3 = np.linspace(2,4,2)
y_value_2 = np.full_like(x3,y3)
plt.plot(x3,y_value_2)
#plt.show()

#for the graph L

x4 = 6
y4 = np.linspace(1,4,4)
x_value_2 = np.full_like(y4,x4)
plt.plot(x_value_2, y4)
#plt.show()

x5 = np.linspace(6,8,2)
y5 = 1
y_value_3 = np.full_like(x5,y5)
plt.plot(x5,y_value_3)
#plt.show()

#for the graph U 
x6 = 10
y6 = np.linspace(1,4,4)
x_value_3 = np.full_like(y6,x6)
plt.plot(x_value_3,y6)
#plt.show()

x7 = np.linspace(10,12,2)
y7 = 1
y_value_4 = np.full_like(x7,y7)
plt.plot(x7, y_value_3)
#plt.show()

x8 = 12
y8 = np.linspace(1,4,4)
x_value_4 = np.full_like(y8,x8)
plt.plot(x_value_4,y8)
plt.show()
